# %% [markdown]
# # Exercicios de repaso EXAME (3) FEBREIRO 2026

# %% [markdown]
# ## Exercicio 1
#
# Dadas as seguintes listas de frutas e de lugares de orixe:
#
#  **frutas = ['manzana', 'plátano', 'kiwi', 'pera', 'fresa']**
#
#  **orixe = ['Asturias', 'Canarias', 'Galicia', 'La Rioja', 'Huelva']**
#
# Percorre as dúas listas mediante un iterable ZIP para escribir por pantalla o nome da fruta e o seu orixe.

# %%
frutas = ['manzana', 'plátano', 'kiwi', 'pera', 'fresa']
orixe = ['Asturias', 'Canarias', 'Galicia', 'La Rioja', 'Huelva']



for fruta, lugar in zip(frutas, orixe):
    print(f"La {fruta} es de {lugar}")
# Out:
# A froita manzana é de Asturias.
# A froita plátano é de Canarias.
# A froita kiwi é de Galicia.
# A froita pera é de La Rioja.
# A froita fresa é de Huelva.

# %%
# solucion

frutas = ['manzana', 'plátano', 'kiwi', 'pera', 'fresa']
orixe = ['Asturias', 'Canarias', 'Galicia', 'La Rioja', 'Huelva']

for fruta, lugar in zip(frutas, orixe):
    print(f"Fruta: {fruta}, Orixe: {lugar}")

# %% [markdown]
# ## Exercicio 2
#
# A partir da listas seguintes, que conteñen o nome de varias cidades galegas e o nº de habitantes das mesmas:
#
#  **cidades = ["Santiago de Compostela", "Vigo", "A Coruña", "Ourense", "Lugo", "Pontevedra"]**
#
#  **habitantes = [ 98179, 292374, 244700, 103756, 97211, 82828]**
#
# Crea un diccionario por comprensión chamado **poboación** no que as claves sexan os nomes das cidades e os valores sexan o dato correspondente á poboación de cada cidade. Para crear o diccionario por comprensión utiliza as dúas listas: **cidades** e **habitantes** e un **"for"** que itere desde 0 ata 5
#
# Fai o mesmo de antes pero usando ZIP.

# %%
cidades = ["Santiago de Compostela", "Vigo", "A Coruña", "Ourense", "Lugo", "Pontevedra"]
habitantes = [ 98179, 292374, 244700, 103756, 97211, 82828]



poboacion = {cidades[i]:habitantes[i] for i in range(len(cidades))}
print(poboacion)

poboacion = {cidade: hab for cidade, hab in zip(cidades,habitantes)}
print(poboacion)
# Out:
# {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828} {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}

# %%
# solucion

cidades = ["Santiago de Compostela", "Vigo", "A Coruña", "Ourense", "Lugo", "Pontevedra"]
habitantes = [ 98179, 292374, 244700, 103756, 97211, 82828]
poboación = {cidades[i] : habitantes[i] for i in range(6)}
print(poboación)
poboación = {C : H for C, H in zip(cidades, habitantes)}
print(poboación)

# %% [markdown]
# ## Exercicio 3
#
# Utilizando o seguinte dicionario que é o resultado do exercicio anterior:
#
# **poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}**
#
# Mostra por pantalla o nome da cidade que teña 97211 habitantes. Para atopala recorre o diccionario cun **"for"** ata dar co primeiro valor que coincida co dato. Atopa unha solución alternativa obtendo as listas de claves e de valores e usando o método index() da lista de valores.
#
# Utilizando a función ***min()*** mostra por pantalla a cidade co menor nº de habitantes e o seu valor.

# %%
poboacion = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}




# Recorrer el diccionario con for
for cidade, hab in poboacion.items():
    if hab == 97211:
        print(f"La ciudad con 97211 habitantes es: {cidade}")
        break
    
    
# Obtener listas de claves y valores
claves = list(poboacion.keys())
valores = list(poboacion.values())

# Buscar el índice del valor 97211
indice = valores.index(97211)

# Obtener la ciudad correspondiente
print(f"La ciudad con 97211 habitantes es: {claves[indice]}")



# Encontrar la ciudad con menos habitantes
cidade_min = min(poboacion, key=poboacion.get)
habitantes_min = poboacion[cidade_min]

print(f"La ciudad con menor población es: {cidade_min} con {habitantes_min} habitantes")
# Out:
# Pontevedra
# 82828

# %%
# solucion

poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}

for clave,valor in poboación.items():
    if valor == 97211:
        print(f"A cidade que ten un nº de habitantes igual a 97211 é: {clave}")
        break

cidades = list(poboación.keys())
habitantes = list(poboación.values())
print(f"A cidade que ten un nº de habitantes igual a 97211 é: {cidades[habitantes.index(97211)]}")

posicion = min(poboación,key=poboación.get)  # Así compara los valores y devuelve la posición (la clave) del más bajo
mínimo = poboación[posicion]                    # Indexando el diccionario obtenemos el valor 
print(f"A cidade co menor nº de habitantes é {posicion} cun valor igual a {mínimo}")

# %% [markdown]
# ## Exercicio 4
#
# Utilizando o mesmo dicionario do exercicio anterior:
#
# **poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}**
#
# Crea unha lista de nome **cidades_grandes** que conteña os nomes das cidades contidas no dicionario que teñan unha poboación igual ou maior a 100.000 de habitantes.

# %%
poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}




cidades_grandes = [ c   for c in poboación.keys() if poboacion[c] >= 100000]

print (cidades_grandes)
# Out:
# ['Vigo', 'A Coruña', 'Ourense']

# %%
# Solucion

poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}

cidades_grandes = [C for C in poboación.keys() if poboación[C]>=100000]
print(cidades_grandes)

# %% [markdown]
# ## Exercicio 5
#
# Utilizando o mesmo dicionario do exercicio anterior:
#
# **poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}**
#
# Escribe por pantalla o dicionario ordenado por nº de habitantes (de menor a maior).

# %%
poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}
print(poboación)




print(dict(sorted(poboación.items(), key=lambda item: item[1], reverse=False)))
# Out:
# {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}
# {'Pontevedra': 82828, 'Lugo': 97211, 'Santiago de Compostela': 98179, 'Ourense': 103756, 'A Coruña': 244700, 'Vigo': 292374}

# %%
# solucion

poboación = {'Santiago de Compostela': 98179, 'Vigo': 292374, 'A Coruña': 244700, 'Ourense': 103756, 'Lugo': 97211, 'Pontevedra': 82828}

for cidade, habitantes in sorted(poboación.items(), key = lambda item: item[1]):
    print(f"{cidade}: {habitantes}")

# %% [markdown]
# ## Exercicio 6
#
# A partir da listas seguintes, que conteñen o nome de varios produtos e os seus prezos:
#
#  **produtos = ["Refresco cola", "Pizza", "Xeado", "Patatas Onduladas", "Salsa Barbacoa"]**
#
#  **prezos = [ 0.90, 3.29, 1.52, 1.91, 2.09]**
#
# Crea un diccionario por comprensión chamado **inventario** no que as claves sexan os nomes dos produtos e os valores sexan os prezos correspondentes ao produto. Para crear o diccionario por comprensión utiliza as dúas listas: **produtos** e **prezos** e un ZIP.

# %%
produtos = ["Refresco cola", "Pizza", "Xeado", "Patacas Onduladas", "Salsa Barbacoa"]
prezos = [ 0.90, 3.29, 1.52, 1.91, 2.09]

inventario = {prod:prez for prod,prez in zip(produtos,prezos)}
print(inventario)


# # ordenar por precio descendente
print(dict(sorted(inventario.items(), key=lambda x:x[1], reverse=True)))

print({prod:prez for prod,prez in sorted(inventario.items(),key=lambda x:x[1], reverse=True)})

# # imprimir productos con precios mayor de 1.50€ en orden ascendente
print({prod:prez for prod,prez in sorted(inventario.items(), key=lambda x:x[1]) if inventario[prod] > 1.50})
print(dict(sorted({prod:prez for prod,prez in inventario.items() if inventario[prod] > 1.50}.items(), key= lambda x:x[1])))










# inventario = {prod:prez for prod, prez in zip(produtos, prezos)}
# print(inventario)


# # ordenar por precio descendente
# print(sorted(inventario.items(), key=lambda item: item[1], reverse=True))
# # formato diccionario
# print(dict(sorted(inventario.items(), key=lambda item: item[1], reverse=True)))
# # imprimir productos con precios mayor de 1.50€ en orden ascendente
# print(sorted({prod:prez for prod, prez in zip(produtos,prezos) if prez > 1.5}.items(), key=lambda item: item[1], reverse=False))
# Out:
# {'Refresco cola': 0.9, 'Pizza': 3.29, 'Xeado': 1.52, 'Patacas Onduladas': 1.91, 'Salsa Barbacoa': 2.09}
# {'Pizza': 3.29, 'Salsa Barbacoa': 2.09, 'Patacas Onduladas': 1.91, 'Xeado': 1.52, 'Refresco cola': 0.9}
# {'Pizza': 3.29, 'Salsa Barbacoa': 2.09, 'Patacas Onduladas': 1.91, 'Xeado': 1.52, 'Refresco cola': 0.9}
# {'Xeado': 1.52, 'Patacas Onduladas': 1.91, 'Salsa Barbacoa': 2.09, 'Pizza': 3.29}
# {'Xeado': 1.52, 'Patacas Onduladas': 1.91, 'Salsa Barbacoa': 2.09, 'Pizza': 3.29}
